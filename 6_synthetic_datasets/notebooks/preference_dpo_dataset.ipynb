# %% [markdown]
# # Generate a dataset for preference alignment
#
# This notebook will guide you through the process of generating a dataset for preference alignment. We'll use the `distilabel` package to generate a dataset for preference alignment.
#
# So let's dig in to some preference alignment datasets.
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; color:black'>
#     <h2 style='margin: 0;color:blue'>Exercise: Generate a dataset for preference alignment</h2>
#     <p>Now that you've seen how to generate a dataset for preference alignment, try generating a dataset for preference alignment.</p>
#     <p><b>Difficulty Levels</b></p>
#     <p>🐢 Generate a dataset for preference alignment</p>
#     <p>🐕 Generate a dataset for preference alignment with response evolution</p>
#     <p>🦁 Generate a dataset for preference alignment with response evolution and model pooling</p>
# </div>

# %% [markdown]
# ## Install dependencies
#
# Instead of transformers, you can also install `vllm` or `hf-inference-endpoints`.

# %%
# !pip install "distilabel[hf-transformers,outlines,instructor]"

# %% [markdown]
# ## Start synthesizing
#
# As we've seen in the previous notebook, we can create a distilabel pipeline for preference dataset generation. The bare minimum pipline is already provided. You can continue work on this pipeline to generate a large dataset for preference alignment. Swap out models, model providers and generation arguments to see how they affect the quality of the dataset. Experiment small, scale up later.
#
# Check out the [distilabel components gallery](https://distilabel.argilla.io/latest/components-gallery/) for information about the processing classes and how to use them.
#
# An example of loading data from the Hub instead of dictionaries is provided below.
#
# ```python
# from datasets import load_dataset
#
# with Pipeline(...) as pipeline:
#     ...
#
# if __name__ == "__main__:
#     dataset = load_dataset("my-dataset", split="train")
#     distiset = pipeline.run(dataset=dataset)
# ```
#
# Don't forget to push your dataset to the Hub after running the pipeline!

# %%
# Based on https://distilabel.argilla.io/1.5.3/sections/pipeline_samples/tutorials/generate_preference_dataset/#convert-to-a-preference-dataset

from distilabel.llms import LiteLLM
from distilabel.pipeline import Pipeline
from distilabel.steps import GroupColumns, LoadDataFromDicts, FormatTextGenerationDPO
from distilabel.steps.tasks import TextGeneration, UltraFeedback

with Pipeline() as pipeline:
    data = LoadDataFromDicts(data=[{"instruction": "What is synthetic data?"}])
    llm_a = LiteLLM(model="deepseek/deepseek-chat")
    llm_b = LiteLLM(model="gemini/gemini-2.5-flash-preview-04-17")
    gen_a = TextGeneration(llm=llm_a)
    gen_b = TextGeneration(llm=llm_b)
    group = GroupColumns(columns=["generation", "model_name"], output_columns=["generations", "models"])
    evaluate_responses = UltraFeedback(
        llm=llm_a,
        aspect="overall-rating"
    )
    format_dpo = FormatTextGenerationDPO()
    data >> [gen_a, gen_b] >> group >> evaluate_responses >> format_dpo

if __name__ == "__main__":
    distiset = pipeline.run()
    # distiset.push_to_hub("lukechen526/huggingface-smol-course-preference-tuning-dataset")
# Out:
# [05/16/25 18:20:19] INFO     ['distilabel.pipeline'] 📝 Pipeline data will be written to               ]8;id=469911;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=632893;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/base.py#1015\1015]8;;\
#                              '/home/vscode/.cache/distilabel/pipelines/pipeline_load_data_from_dicts_0
#                              _text_generation_0_text_generation_1_group_columns_0_ultra_feedback_0_for
#                              mat_text_generation_d_p_o_0/c8394f30d37ed829266bc1ef9bf4c04cd096c46b/exec
#                              utions/627dccd6cbccf275e65709d60d9e2bc842e823cf/data/steps_outputs'
#                     INFO     ['distilabel.pipeline'] ⌛ The steps of the pipeline will be loaded in    ]8;id=718797;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=574962;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/base.py#1046\1046]8;;\
#                              stages:
#                               * Legend: 🚰 GeneratorStep 🌐 GlobalStep 🔄 Step
#                               * Stage 0:
#                                 - 🚰 'load_data_from_dicts_0'
#                                 - 🔄 'text_generation_0'
#                                 - 🔄 'text_generation_1'
#                                 - 🔄 'group_columns_0'
#                                 - 🔄 'ultra_feedback_0'
#                                 - 🔄 'format_text_generation_d_p_o_0'
#                     INFO     ['distilabel.pipeline'] ⏳ Waiting for all the steps of stage 0 to        ]8;id=129486;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=789922;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/base.py#1382\1382]8;;\
#                              load...
# [05/16/25 18:20:21] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 3/6                 ]8;id=82140;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=656643;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 0/1
#                               * 'text_generation_1' replicas: 0/1
#                               * 'group_columns_0' replicas: 1/1
#                               * 'ultra_feedback_0' replicas: 0/1
#                               * 'format_text_generation_d_p_o_0' replicas: 1/1
# [05/16/25 18:20:24] INFO     ['distilabel.pipeline'] ⏳ Steps from stage 0 loaded: 6/6                 ]8;id=299091;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=343313;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/base.py#1418\1418]8;;\
#                               * 'load_data_from_dicts_0' replicas: 1/1
#                               * 'text_generation_0' replicas: 1/1
#                               * 'text_generation_1' replicas: 1/1
#                               * 'group_columns_0' replicas: 1/1
#                               * 'ultra_feedback_0' replicas: 1/1
#                               * 'format_text_generation_d_p_o_0' replicas: 1/1
#                     INFO     ['distilabel.pipeline'] ✅ All the steps from stage 0 have been loaded!   ]8;id=661750;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/base.py\base.py]8;;\:]8;id=819499;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/base.py#1422\1422]8;;\
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🚰 Starting yielding    ]8;id=671661;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=675600;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#179\179]8;;\
#                              batches from generator step 'load_data_from_dicts_0'. Offset: 0
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 📨 Step                 ]8;id=392912;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=914091;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              'load_data_from_dicts_0' sending batch 0 to output queue
#                     INFO     ['distilabel.step.load_data_from_dicts_0'] 🏁 Finished running     ]8;id=959227;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=683242;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              step 'load_data_from_dicts_0' (replica ID: 0)
#                     INFO     ['distilabel.step.text_generation_1'] 📦 Processing batch 0 in     ]8;id=298567;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=347410;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#230\230]8;;\
#                              'text_generation_1' (replica ID: 0)
#                     INFO     ['distilabel.step.text_generation_0'] 📦 Processing batch 0 in     ]8;id=220796;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=12412;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#230\230]8;;\
#                              'text_generation_0' (replica ID: 0)
# [05/16/25 18:20:35] INFO     ['distilabel.step.text_generation_1'] 📨 Step 'text_generation_1'  ]8;id=76343;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=770238;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              sending batch 0 to output queue
#                     INFO     ['distilabel.step.text_generation_1'] 🏁 Finished running step     ]8;id=902047;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=643287;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              'text_generation_1' (replica ID: 0)
# [05/16/25 18:20:46] INFO     ['distilabel.step.text_generation_0'] 📨 Step 'text_generation_0'  ]8;id=57324;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=410229;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              sending batch 0 to output queue
#                     INFO     ['distilabel.step.text_generation_0'] 🏁 Finished running step     ]8;id=832295;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=622612;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              'text_generation_0' (replica ID: 0)
#                     INFO     ['distilabel.step.group_columns_0'] 📦 Processing batch 0 in       ]8;id=961617;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=738502;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#230\230]8;;\
#                              'group_columns_0' (replica ID: 0)
#                     INFO     ['distilabel.step.group_columns_0'] 📨 Step 'group_columns_0'      ]8;id=381126;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=317221;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              sending batch 0 to output queue
#                     INFO     ['distilabel.step.group_columns_0'] 🏁 Finished running step       ]8;id=586378;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=455803;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              'group_columns_0' (replica ID: 0)
#                     INFO     ['distilabel.step.ultra_feedback_0'] 📦 Processing batch 0 in      ]8;id=672566;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=660735;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#230\230]8;;\
#                              'ultra_feedback_0' (replica ID: 0)
# [05/16/25 18:20:58] INFO     ['distilabel.step.ultra_feedback_0'] 📨 Step 'ultra_feedback_0'    ]8;id=291895;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=918317;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              sending batch 0 to output queue
#                     INFO     ['distilabel.step.ultra_feedback_0'] 🏁 Finished running step      ]8;id=136489;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=980793;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              'ultra_feedback_0' (replica ID: 0)
#                     INFO     ['distilabel.step.format_text_generation_d_p_o_0'] 📦 Processing   ]8;id=731406;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=62141;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#230\230]8;;\
#                              batch 0 in 'format_text_generation_d_p_o_0' (replica ID: 0)
#                     INFO     ['distilabel.step.format_text_generation_d_p_o_0'] 📨 Step         ]8;id=146783;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=832016;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#290\290]8;;\
#                              'format_text_generation_d_p_o_0' sending batch 0 to output queue
#                     INFO     ['distilabel.step.format_text_generation_d_p_o_0'] 🏁 Finished     ]8;id=939627;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py\step_wrapper.py]8;;\:]8;id=123137;file:///workspaces/smol-course/.venv/lib/python3.11/site-packages/distilabel/pipeline/step_wrapper.py#129\129]8;;\
#                              running step 'format_text_generation_d_p_o_0' (replica ID: 0)
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
import pprint
pprint.pprint(distiset['default']['train'][0])
# Out:
# {'chosen': [{'content': 'What is synthetic data?', 'role': 'user'},
#             {'content': '**Synthetic data** is artificially generated data '
#                         'that mimics real-world data but is created using '
#                         'algorithms, simulations, or generative models rather '
#                         'than being collected from actual events or '
#                         'measurements. It is designed to retain the '
#                         'statistical properties and patterns of real data '
#                         'while avoiding privacy, legal, or logistical '
#                         'constraints.\n'
#                         '\n'
#                         '### **Key Characteristics of Synthetic Data:**\n'
#                         '1. **Privacy-Preserving** – Since it’s not derived '
#                         'from real individuals, it avoids exposing sensitive '
#                         'information (e.g., medical records, financial data).\n'
#                         '2. **Scalable** – Can be generated in large '
#                         'quantities to augment limited real datasets.\n'
#                         '3. **Controlled & Customizable** – Allows simulation '
#                         'of rare or edge-case scenarios that may be hard to '
#                         'collect in reality.\n'
#                         '4. **Cost-Efficient** – Reduces the need for '
#                         'expensive data collection processes.\n'
#                         '\n'
#                         '### **How is Synthetic Data Generated?**\n'
#                         '- **Rule-Based Models:** Manually defined rules or '
#                         'statistical distributions.\n'
#                         '- **Generative AI:** Machine learning models like '
#                         '**Generative Adversarial Networks (GANs)**, '
#                         '**Variational Autoencoders (VAEs)**, or **diffusion '
#                         'models** create realistic synthetic data.\n'
#                         '- **Simulation:** Virtual environments (e.g., '
#                         'self-driving car training in simulated traffic).\n'
#                         '\n'
#                         '### **Use Cases:**\n'
#                         '- **AI/ML Training** – Enhances datasets where real '
#                         'data is scarce (e.g., healthcare, fraud detection).\n'
#                         '- **Testing & Development** – Provides data for '
#                         'software testing without risking real user '
#                         'information.\n'
#                         '- **Privacy Compliance** – Helps comply with GDPR, '
#                         'HIPAA, etc., by avoiding real personal data.\n'
#                         '- **Research & Benchmarking** – Enables '
#                         'experimentation without access to proprietary '
#                         'datasets.\n'
#                         '\n'
#                         '### **Challenges:**\n'
#                         '- **Quality & Realism** – Poorly generated data may '
#                         'not accurately reflect real-world conditions.\n'
#                         '- **Bias** – If the source data or generation process '
#                         'is biased, synthetic data inherits those biases.\n'
#                         '- **Validation** – Requires rigorous testing to '
#                         'ensure usefulness.\n'
#                         '\n'
#                         'Synthetic data is increasingly vital in AI, '
#                         'cybersecurity, finance, and healthcare, offering a '
#                         'balance between utility and privacy. Would you like '
#                         'examples of tools or frameworks for generating it?',
#              'role': 'assistant'}],
#  'chosen_rating': 5,
#  'distilabel_metadata': {'raw_input_ultra_feedback_0': [{'content': 'Your role '
#                                                                     'is to '
#                                                                     'evaluate '
#                                                                     'text '
#                                                                     'quality '
#                                                                     'based on '
#                                                                     'given '
#                                                                     'criteria.\n'
#                                                                     "You'll "
#                                                                     'receive '
#                                                                     'an '
#                                                                     'instructional '
#                                                                     'description '
#                                                                     '("Instruction") '
#                                                                     'and 2 '
#                                                                     'text '
#                                                                     'outputs '
#                                                                     '("Text").\n'
#                                                                     'Understand '
#                                                                     'and '
#                                                                     'interpret '
#                                                                     'instructions '
#                                                                     'to '
#                                                                     'evaluate '
#                                                                     'effectively.\n'
#                                                                     'Provide '
#                                                                     'annotations '
#                                                                     'for each '
#                                                                     'text with '
#                                                                     'a rating '
#                                                                     'and '
#                                                                     'rationale.\n'
#                                                                     'The 2 '
#                                                                     'texts '
#                                                                     'given are '
#                                                                     'independent, '
#                                                                     'and '
#                                                                     'should be '
#                                                                     'evaluated '
#                                                                     'separately.\n',
#                                                          'role': 'system'},
#                                                         {'content': '# General '
#                                                                     'Text '
#                                                                     'Quality '
#                                                                     'Assessment\n'
#                                                                     '\n'
#                                                                     'Evaluate '
#                                                                     'the '
#                                                                     "model's "
#                                                                     'outputs '
#                                                                     'based on '
#                                                                     'various '
#                                                                     'criteria:\n'
#                                                                     '\n'
#                                                                     '1. '
#                                                                     '**Correctness '
#                                                                     '& '
#                                                                     'Informativeness**: '
#                                                                     'Does the '
#                                                                     'output '
#                                                                     'provide '
#                                                                     'accurate '
#                                                                     'and '
#                                                                     'helpful '
#                                                                     'information?\n'
#                                                                     '2. '
#                                                                     '**Honesty '
#                                                                     '& '
#                                                                     'Uncertainty**: '
#                                                                     'How '
#                                                                     'confidently '
#                                                                     'does the '
#                                                                     'model '
#                                                                     'convey '
#                                                                     'its '
#                                                                     'information, '
#                                                                     'and does '
#                                                                     'it '
#                                                                     'express '
#                                                                     'uncertainty '
#                                                                     'appropriately?\n'
#                                                                     '3. '
#                                                                     '**Truthfulness '
#                                                                     '& '
#                                                                     'Hallucination**: '
#                                                                     'Does the '
#                                                                     'model '
#                                                                     'introduce '
#                                                                     'misleading '
#                                                                     'or '
#                                                                     'fabricated '
#                                                                     'details?\n'
#                                                                     '4. '
#                                                                     '**Instruction '
#                                                                     'Following**: '
#                                                                     'Does the '
#                                                                     "model's "
#                                                                     'output '
#                                                                     'align '
#                                                                     'with '
#                                                                     'given '
#                                                                     'instructions '
#                                                                     'and the '
#                                                                     "user's "
#                                                                     'intent?\n'
#                                                                     '\n'
#                                                                     'Your role '
#                                                                     'is to '
#                                                                     'provide a '
#                                                                     'holistic '
#                                                                     'assessment '
#                                                                     'considering '
#                                                                     'all the '
#                                                                     'above '
#                                                                     'factors.\n'
#                                                                     '\n'
#                                                                     '**Scoring**: '
#                                                                     'Rate '
#                                                                     'outputs 1 '
#                                                                     'to 5 '
#                                                                     'based on '
#                                                                     'the '
#                                                                     'overall '
#                                                                     'quality, '
#                                                                     'considering '
#                                                                     'all '
#                                                                     'aspects:\n'
#                                                                     '1. **Low '
#                                                                     'Quality**: '
#                                                                     'Contains '
#                                                                     'inaccuracies, '
#                                                                     'may be '
#                                                                     'entirely '
#                                                                     'wrong or '
#                                                                     'has '
#                                                                     'severe '
#                                                                     'hallucinations.\n'
#                                                                     '2. '
#                                                                     '**Moderate '
#                                                                     'Quality**: '
#                                                                     'Addresses '
#                                                                     'some '
#                                                                     'aspects, '
#                                                                     'but has '
#                                                                     'errors or '
#                                                                     'is '
#                                                                     'partially '
#                                                                     'aligned '
#                                                                     'with '
#                                                                     'instructions.\n'
#                                                                     '3. '
#                                                                     '**Good**: '
#                                                                     'Generally '
#                                                                     'accurate '
#                                                                     'but may '
#                                                                     'contain '
#                                                                     'minor '
#                                                                     'errors or '
#                                                                     'slight '
#                                                                     'deviations.\n'
#                                                                     '4. **Very '
#                                                                     'Good**: '
#                                                                     'Near '
#                                                                     'perfect, '
#                                                                     'with '
#                                                                     'minor '
#                                                                     'issues in '
#                                                                     'terms of '
#                                                                     'alignment '
#                                                                     'or '
#                                                                     'confidence.\n'
#                                                                     '5, '
#                                                                     '**Excellent**: '
#                                                                     'Accurate, '
#                                                                     'confident, '
#                                                                     'aligned '
#                                                                     'with '
#                                                                     'instructions, '
#                                                                     'and free '
#                                                                     'of '
#                                                                     'hallucinations.\n'
#                                                                     '\n'
#                                                                     '## '
#                                                                     'Format:\n'
#                                                                     '\n'
#                                                                     '### '
#                                                                     'Input\n'
#                                                                     'Instruction: '
#                                                                     '[Clearly '
#                                                                     'specify '
#                                                                     'the task '
#                                                                     'goal and '
#                                                                     'restrictions]\n'
#                                                                     '\n'
#                                                                     'Texts:\n'
#                                                                     '<text 1> '
#                                                                     '[Text 1]\n'
#                                                                     '<text 2> '
#                                                                     '[Text 2]\n'
#                                                                     '\n'
#                                                                     '### '
#                                                                     'Output\n'
#                                                                     '#### '
#                                                                     'Output '
#                                                                     'for Text '
#                                                                     '1\n'
#                                                                     'Rating: '
#                                                                     '[Rating '
#                                                                     'for text '
#                                                                     '1]\n'
#                                                                     'Rationale: '
#                                                                     '[Rationale '
#                                                                     'for the '
#                                                                     'rating in '
#                                                                     'short '
#                                                                     'sentences]\n'
#                                                                     '\n'
#                                                                     '#### '
#                                                                     'Output '
#                                                                     'for Text '
#                                                                     '2\n'
#                                                                     'Rating: '
#                                                                     '[Rating]\n'
#                                                                     'Rationale: '
#                                                                     '[Rationale]\n'
#                                                                     '\n'
#                                                                     '---\n'
#                                                                     '\n'
#                                                                     '## '
#                                                                     'Annotation\n'
#                                                                     '\n'
#                                                                     '### '
#                                                                     'Input\n'
#                                                                     'Instruction: '
#                                                                     'What is '
#                                                                     'synthetic '
#                                                                     'data?\n'
#                                                                     '\n'
#                                                                     'Texts:\n'
#                                                                     '<text 1> '
#                                                                     '**Synthetic '
#                                                                     'data** is '
#                                                                     'artificially '
#                                                                     'generated '
#                                                                     'data that '
#                                                                     'mimics '
#                                                                     'real-world '
#                                                                     'data but '
#                                                                     'is '
#                                                                     'created '
#                                                                     'using '
#                                                                     'algorithms, '
#                                                                     'simulations, '
#                                                                     'or '
#                                                                     'generative '
#                                                                     'models '
#                                                                     'rather '
#                                                                     'than '
#                                                                     'being '
#                                                                     'collected '
#                                                                     'from '
#                                                                     'actual '
#                                                                     'events or '
#                                                                     'measurements. '
#                                                                     'It is '
#                                                                     'designed '
#                                                                     'to retain '
#                                                                     'the '
#                                                                     'statistical '
#                                                                     'properties '
#                                                                     'and '
#                                                                     'patterns '
#                                                                     'of real '
#                                                                     'data '
#                                                                     'while '
#                                                                     'avoiding '
#                                                                     'privacy, '
#                                                                     'legal, or '
#                                                                     'logistical '
#                                                                     'constraints.\n'
#                                                                     '\n'
#                                                                     '### **Key '
#                                                                     'Characteristics '
#                                                                     'of '
#                                                                     'Synthetic '
#                                                                     'Data:**\n'
#                                                                     '1. '
#                                                                     '**Privacy-Preserving** '
#                                                                     '– Since '
#                                                                     'it’s not '
#                                                                     'derived '
#                                                                     'from real '
#                                                                     'individuals, '
#                                                                     'it avoids '
#                                                                     'exposing '
#                                                                     'sensitive '
#                                                                     'information '
#                                                                     '(e.g., '
#                                                                     'medical '
#                                                                     'records, '
#                                                                     'financial '
#                                                                     'data).\n'
#                                                                     '2. '
#                                                                     '**Scalable** '
#                                                                     '– Can be '
#                                                                     'generated '
#                                                                     'in large '
#                                                                     'quantities '
#                                                                     'to '
#                                                                     'augment '
#                                                                     'limited '
#                                                                     'real '
#                                                                     'datasets.\n'
#                                                                     '3. '
#                                                                     '**Controlled '
#                                                                     '& '
#                                                                     'Customizable** '
#                                                                     '– Allows '
#                                                                     'simulation '
#                                                                     'of rare '
#                                                                     'or '
#                                                                     'edge-case '
#                                                                     'scenarios '
#                                                                     'that may '
#                                                                     'be hard '
#                                                                     'to '
#                                                                     'collect '
#                                                                     'in '
#                                                                     'reality.\n'
#                                                                     '4. '
#                                                                     '**Cost-Efficient** '
#                                                                     '– Reduces '
#                                                                     'the need '
#                                                                     'for '
#                                                                     'expensive '
#                                                                     'data '
#                                                                     'collection '
#                                                                     'processes.\n'
#                                                                     '\n'
#                                                                     '### **How '
#                                                                     'is '
#                                                                     'Synthetic '
#                                                                     'Data '
#                                                                     'Generated?**\n'
#                                                                     '- '
#                                                                     '**Rule-Based '
#                                                                     'Models:** '
#                                                                     'Manually '
#                                                                     'defined '
#                                                                     'rules or '
#                                                                     'statistical '
#                                                                     'distributions.\n'
#                                                                     '- '
#                                                                     '**Generative '
#                                                                     'AI:** '
#                                                                     'Machine '
#                                                                     'learning '
#                                                                     'models '
#                                                                     'like '
#                                                                     '**Generative '
#                                                                     'Adversarial '
#                                                                     'Networks '
#                                                                     '(GANs)**, '
#                                                                     '**Variational '
#                                                                     'Autoencoders '
#                                                                     '(VAEs)**, '
#                                                                     'or '
#                                                                     '**diffusion '
#                                                                     'models** '
#                                                                     'create '
#                                                                     'realistic '
#                                                                     'synthetic '
#                                                                     'data.\n'
#                                                                     '- '
#                                                                     '**Simulation:** '
#                                                                     'Virtual '
#                                                                     'environments '
#                                                                     '(e.g., '
#                                                                     'self-driving '
#                                                                     'car '
#                                                                     'training '
#                                                                     'in '
#                                                                     'simulated '
#                                                                     'traffic).\n'
#                                                                     '\n'
#                                                                     '### **Use '
#                                                                     'Cases:**\n'
#                                                                     '- **AI/ML '
#                                                                     'Training** '
#                                                                     '– '
#                                                                     'Enhances '
#                                                                     'datasets '
#                                                                     'where '
#                                                                     'real data '
#                                                                     'is scarce '
#                                                                     '(e.g., '
#                                                                     'healthcare, '
#                                                                     'fraud '
#                                                                     'detection).\n'
#                                                                     '- '
#                                                                     '**Testing '
#                                                                     '& '
#                                                                     'Development** '
#                                                                     '– '
#                                                                     'Provides '
#                                                                     'data for '
#                                                                     'software '
#                                                                     'testing '
#                                                                     'without '
#                                                                     'risking '
#                                                                     'real user '
#                                                                     'information.\n'
#                                                                     '- '
#                                                                     '**Privacy '
#                                                                     'Compliance** '
#                                                                     '– Helps '
#                                                                     'comply '
#                                                                     'with '
#                                                                     'GDPR, '
#                                                                     'HIPAA, '
#                                                                     'etc., by '
#                                                                     'avoiding '
#                                                                     'real '
#                                                                     'personal '
#                                                                     'data.\n'
#                                                                     '- '
#                                                                     '**Research '
#                                                                     '& '
#                                                                     'Benchmarking** '
#                                                                     '– Enables '
#                                                                     'experimentation '
#                                                                     'without '
#                                                                     'access to '
#                                                                     'proprietary '
#                                                                     'datasets.\n'
#                                                                     '\n'
#                                                                     '### '
#                                                                     '**Challenges:**\n'
#                                                                     '- '
#                                                                     '**Quality '
#                                                                     '& '
#                                                                     'Realism** '
#                                                                     '– Poorly '
#                                                                     'generated '
#                                                                     'data may '
#                                                                     'not '
#                                                                     'accurately '
#                                                                     'reflect '
#                                                                     'real-world '
#                                                                     'conditions.\n'
#                                                                     '- '
#                                                                     '**Bias** '
#                                                                     '– If the '
#                                                                     'source '
#                                                                     'data or '
#                                                                     'generation '
#                                                                     'process '
#                                                                     'is '
#                                                                     'biased, '
#                                                                     'synthetic '
#                                                                     'data '
#                                                                     'inherits '
#                                                                     'those '
#                                                                     'biases.\n'
#                                                                     '- '
#                                                                     '**Validation** '
#                                                                     '– '
#                                                                     'Requires '
#                                                                     'rigorous '
#                                                                     'testing '
#                                                                     'to ensure '
#                                                                     'usefulness.\n'
#                                                                     '\n'
#                                                                     'Synthetic '
#                                                                     'data is '
#                                                                     'increasingly '
#                                                                     'vital in '
#                                                                     'AI, '
#                                                                     'cybersecurity, '
#                                                                     'finance, '
#                                                                     'and '
#                                                                     'healthcare, '
#                                                                     'offering '
#                                                                     'a balance '
#                                                                     'between '
#                                                                     'utility '
#                                                                     'and '
#                                                                     'privacy. '
#                                                                     'Would you '
#                                                                     'like '
#                                                                     'examples '
#                                                                     'of tools '
#                                                                     'or '
#                                                                     'frameworks '
#                                                                     'for '
#                                                                     'generating '
#                                                                     'it?\n'
#                                                                     '<text 2> '
#                                                                     'In simple '
#                                                                     'terms, '
#                                                                     '**synthetic '
#                                                                     'data is '
#                                                                     'data that '
#                                                                     'is '
#                                                                     'artificially '
#                                                                     'generated '
#                                                                     'rather '
#                                                                     'than '
#                                                                     'produced '
#                                                                     'from '
#                                                                     'real-world '
#                                                                     'events or '
#                                                                     'observations.**\n'
#                                                                     '\n'
#                                                                     'Instead '
#                                                                     'of '
#                                                                     'collecting '
#                                                                     'information '
#                                                                     'through '
#                                                                     'surveys, '
#                                                                     'sensors, '
#                                                                     'transactions, '
#                                                                     'or other '
#                                                                     'real-world '
#                                                                     'processes, '
#                                                                     'synthetic '
#                                                                     'data is '
#                                                                     'created '
#                                                                     'using '
#                                                                     'algorithms, '
#                                                                     'simulations, '
#                                                                     'statistical '
#                                                                     'models, '
#                                                                     'or '
#                                                                     'rule-based '
#                                                                     'systems.\n'
#                                                                     '\n'
#                                                                     "Here's a "
#                                                                     'breakdown '
#                                                                     'of what '
#                                                                     'that '
#                                                                     'means and '
#                                                                     "why it's "
#                                                                     'used:\n'
#                                                                     '\n'
#                                                                     '**Key '
#                                                                     'Characteristics:**\n'
#                                                                     '\n'
#                                                                     '1.  '
#                                                                     '**Artificial:** '
#                                                                     "It's not "
#                                                                     'based on '
#                                                                     'actual '
#                                                                     'individuals, '
#                                                                     'events, '
#                                                                     'or '
# ...
#                  'mimics real-world data but is created using algorithms, '
#                  'simulations, or generative models rather than being '
#                  'collected from actual events or measurements. It is designed '
#                  'to retain the statistical properties and patterns of real '
#                  'data while avoiding privacy, legal, or logistical '
#                  'constraints.\n'
#                  '\n'
#                  '### **Key Characteristics of Synthetic Data:**\n'
#                  '1. **Privacy-Preserving** – Since it’s not derived from real '
#                  'individuals, it avoids exposing sensitive information (e.g., '
#                  'medical records, financial data).\n'
#                  '2. **Scalable** – Can be generated in large quantities to '
#                  'augment limited real datasets.\n'
#                  '3. **Controlled & Customizable** – Allows simulation of rare '
#                  'or edge-case scenarios that may be hard to collect in '
#                  'reality.\n'
#                  '4. **Cost-Efficient** – Reduces the need for expensive data '
#                  'collection processes.\n'
#                  '\n'
#                  '### **How is Synthetic Data Generated?**\n'
#                  '- **Rule-Based Models:** Manually defined rules or '
#                  'statistical distributions.\n'
#                  '- **Generative AI:** Machine learning models like '
#                  '**Generative Adversarial Networks (GANs)**, **Variational '
#                  'Autoencoders (VAEs)**, or **diffusion models** create '
#                  'realistic synthetic data.\n'
#                  '- **Simulation:** Virtual environments (e.g., self-driving '
#                  'car training in simulated traffic).\n'
#                  '\n'
#                  '### **Use Cases:**\n'
#                  '- **AI/ML Training** – Enhances datasets where real data is '
#                  'scarce (e.g., healthcare, fraud detection).\n'
#                  '- **Testing & Development** – Provides data for software '
#                  'testing without risking real user information.\n'
#                  '- **Privacy Compliance** – Helps comply with GDPR, HIPAA, '
#                  'etc., by avoiding real personal data.\n'
#                  '- **Research & Benchmarking** – Enables experimentation '
#                  'without access to proprietary datasets.\n'
#                  '\n'
#                  '### **Challenges:**\n'
#                  '- **Quality & Realism** – Poorly generated data may not '
#                  'accurately reflect real-world conditions.\n'
#                  '- **Bias** – If the source data or generation process is '
#                  'biased, synthetic data inherits those biases.\n'
#                  '- **Validation** – Requires rigorous testing to ensure '
#                  'usefulness.\n'
#                  '\n'
#                  'Synthetic data is increasingly vital in AI, cybersecurity, '
#                  'finance, and healthcare, offering a balance between utility '
#                  'and privacy. Would you like examples of tools or frameworks '
#                  'for generating it?',
#                  'In simple terms, **synthetic data is data that is '
#                  'artificially generated rather than produced from real-world '
#                  'events or observations.**\n'
#                  '\n'
#                  'Instead of collecting information through surveys, sensors, '
#                  'transactions, or other real-world processes, synthetic data '
#                  'is created using algorithms, simulations, statistical '
#                  'models, or rule-based systems.\n'
#                  '\n'
#                  "Here's a breakdown of what that means and why it's used:\n"
#                  '\n'
#                  '**Key Characteristics:**\n'
#                  '\n'
#                  "1.  **Artificial:** It's not based on actual individuals, "
#                  'events, or measurements that occurred in reality.\n'
#                  "2.  **Simulates Reality:** It's designed to reflect the "
#                  'properties, patterns, relationships, and statistical '
#                  'distributions of real-world data. The goal is often for it '
#                  'to be statistically equivalent or indistinguishable from '
#                  'real data for a specific purpose.\n'
#                  "3.  **Generated by Algorithms:** It's created using various "
#                  'computational techniques, from simple rules to complex '
#                  'machine learning models (like GANs or VAEs).\n'
#                  '\n'
#                  '**Why is Synthetic Data Used?**\n'
#                  '\n'
#                  'There are several primary motivations for using synthetic '
#                  'data:\n'
#                  '\n'
#                  '1.  **Privacy and Security:** Real data often contains '
#                  'sensitive personal or proprietary information. Synthetic '
#                  'data can mimic the characteristics of real data without '
#                  'containing any original records, making it safe to share or '
#                  'use while complying with privacy regulations (like GDPR or '
#                  'HIPAA).\n'
#                  '2.  **Data Scarcity / Augmentation:** For rare events (e.g., '
#                  'specific types of medical conditions, unusual fraud '
#                  'patterns, autonomous driving edge cases) or for building '
#                  'entirely new systems where no real data exists yet, '
#                  'synthetic data can generate large, diverse datasets for '
#                  'training or testing.\n'
#                  '3.  **Cost and Time Reduction:** Collecting and annotating '
#                  'real data can be expensive and time-consuming. Generating '
#                  'synthetic data can often be faster and more cost-effective, '
#                  'especially in fields like computer vision where labeling '
#                  'images is labor-intensive.\n'
#                  '4.  **Bias Reduction:** If a real dataset is biased towards '
#                  'certain demographics or conditions, synthetic data can be '
#                  'generated to balance the dataset and potentially reduce bias '
#                  'in models trained on it.\n'
#                  '5.  **Testing and Development:** Synthetic data is excellent '
#                  'for robust testing of software systems, algorithms, and '
#                  'machine learning models, allowing developers to test edge '
#                  'cases and ensure performance before deploying with real '
#                  'data.\n'
#                  '\n'
#                  '**How is it Generated?**\n'
#                  '\n'
#                  'Synthetic data can be generated in various ways, ranging '
#                  'from simple to complex:\n'
#                  '\n'
#                  '*   **Rule-Based Systems:** Creating data based on '
#                  'predefined rules and constraints.\n'
#                  '*   **Statistical Methods:** Generating data that matches '
#                  'the statistical properties (means, variances, correlations) '
#                  'of a real dataset without individual records.\n'
#                  '*   **Generative Models (Machine Learning):** Using '
#                  'sophisticated ML models like Generative Adversarial Networks '
#                  '(GANs) or Variational Autoencoders (VAEs) to learn the '
#                  'underlying patterns and realistic representations from real '
#                  'data (or simulate them) and then create new, '
#                  'realistic-looking synthetic data.\n'
#                  '\n'
#                  '**In Summary:**\n'
#                  '\n'
#                  'Synthetic data is a powerful tool that allows organizations '
#                  'and researchers to overcome limitations associated with real '
#                  'data, such as privacy concerns, scarcity, cost, and bias. By '
#                  'creating artificial datasets that mimic the properties of '
#                  'reality, it enables privacy-preserving data sharing, '
#                  'accelerates development, and improves the training of AI and '
#                  'machine learning models.'],
#  'instruction': 'What is synthetic data?',
#  'model_name': 'deepseek/deepseek-chat',
#  'models': ['deepseek/deepseek-chat', 'gemini/gemini-2.5-flash-preview-04-17'],
#  'prompt': 'What is synthetic data?',
#  'prompt_id': 'd526db7f44bf2beec815076670b76e4b1614c571df382f44674bdba8d4daa976',
#  'ratings': [5, 4],
#  'rationales': ['The text provides a comprehensive and accurate definition of '
#                 'synthetic data, detailing its key characteristics, generation '
#                 'methods, use cases, and challenges. It is informative, '
#                 'well-structured, and aligns perfectly with the instruction. '
#                 'The model confidently conveys the information without any '
#                 'signs of uncertainty or hallucination.',
#                 'The text offers a clear and concise explanation of synthetic '
#                 'data, covering its artificial nature, simulation of reality, '
#                 'and generation methods. It also discusses the motivations for '
#                 'using synthetic data effectively. While it is accurate and '
#                 'informative, it lacks some of the depth and detail provided '
#                 'in Text 1, such as specific examples of generative models or '
#                 'challenges like bias and validation. The alignment with the '
#                 'instruction is strong, but the content is slightly less '
#                 'comprehensive.'],
#  'rejected': [{'content': 'What is synthetic data?', 'role': 'user'},
#               {'content': 'In simple terms, **synthetic data is data that is '
#                           'artificially generated rather than produced from '
#                           'real-world events or observations.**\n'
#                           '\n'
#                           'Instead of collecting information through surveys, '
#                           'sensors, transactions, or other real-world '
#                           'processes, synthetic data is created using '
#                           'algorithms, simulations, statistical models, or '
#                           'rule-based systems.\n'
#                           '\n'
#                           "Here's a breakdown of what that means and why it's "
#                           'used:\n'
#                           '\n'
#                           '**Key Characteristics:**\n'
#                           '\n'
#                           "1.  **Artificial:** It's not based on actual "
#                           'individuals, events, or measurements that occurred '
#                           'in reality.\n'
#                           "2.  **Simulates Reality:** It's designed to reflect "
#                           'the properties, patterns, relationships, and '
#                           'statistical distributions of real-world data. The '
#                           'goal is often for it to be statistically equivalent '
#                           'or indistinguishable from real data for a specific '
#                           'purpose.\n'
#                           "3.  **Generated by Algorithms:** It's created using "
#                           'various computational techniques, from simple rules '
#                           'to complex machine learning models (like GANs or '
#                           'VAEs).\n'
#                           '\n'
#                           '**Why is Synthetic Data Used?**\n'
#                           '\n'
#                           'There are several primary motivations for using '
#                           'synthetic data:\n'
#                           '\n'
#                           '1.  **Privacy and Security:** Real data often '
#                           'contains sensitive personal or proprietary '
#                           'information. Synthetic data can mimic the '
#                           'characteristics of real data without containing any '
#                           'original records, making it safe to share or use '
#                           'while complying with privacy regulations (like GDPR '
#                           'or HIPAA).\n'
#                           '2.  **Data Scarcity / Augmentation:** For rare '
#                           'events (e.g., specific types of medical conditions, '
#                           'unusual fraud patterns, autonomous driving edge '
#                           'cases) or for building entirely new systems where '
#                           'no real data exists yet, synthetic data can '
#                           'generate large, diverse datasets for training or '
#                           'testing.\n'
#                           '3.  **Cost and Time Reduction:** Collecting and '
#                           'annotating real data can be expensive and '
#                           'time-consuming. Generating synthetic data can often '
#                           'be faster and more cost-effective, especially in '
#                           'fields like computer vision where labeling images '
#                           'is labor-intensive.\n'
#                           '4.  **Bias Reduction:** If a real dataset is biased '
#                           'towards certain demographics or conditions, '
#                           'synthetic data can be generated to balance the '
#                           'dataset and potentially reduce bias in models '
#                           'trained on it.\n'
#                           '5.  **Testing and Development:** Synthetic data is '
#                           'excellent for robust testing of software systems, '
#                           'algorithms, and machine learning models, allowing '
#                           'developers to test edge cases and ensure '
#                           'performance before deploying with real data.\n'
#                           '\n'
#                           '**How is it Generated?**\n'
#                           '\n'
#                           'Synthetic data can be generated in various ways, '
#                           'ranging from simple to complex:\n'
#                           '\n'
#                           '*   **Rule-Based Systems:** Creating data based on '
#                           'predefined rules and constraints.\n'
#                           '*   **Statistical Methods:** Generating data that '
#                           'matches the statistical properties (means, '
#                           'variances, correlations) of a real dataset without '
#                           'individual records.\n'
#                           '*   **Generative Models (Machine Learning):** Using '
#                           'sophisticated ML models like Generative Adversarial '
#                           'Networks (GANs) or Variational Autoencoders (VAEs) '
#                           'to learn the underlying patterns and realistic '
#                           'representations from real data (or simulate them) '
#                           'and then create new, realistic-looking synthetic '
#                           'data.\n'
#                           '\n'
#                           '**In Summary:**\n'
#                           '\n'
#                           'Synthetic data is a powerful tool that allows '
#                           'organizations and researchers to overcome '
#                           'limitations associated with real data, such as '
#                           'privacy concerns, scarcity, cost, and bias. By '
#                           'creating artificial datasets that mimic the '
#                           'properties of reality, it enables '
#                           'privacy-preserving data sharing, accelerates '
#                           'development, and improves the training of AI and '
#                           'machine learning models.',
#                'role': 'assistant'}],
#  'rejected_rating': 4}

# %% [markdown]
# ## 🌯 That's a wrap
#
# You've now seen how to generate a dataset for preference alignment. You could use this to:
#
# - Generate a dataset for preference alignment.
# - Create evaluation datasets for preference alignment.
#
# Next
#
# 🏋️‍♂️ Fine-tune a model with preference alignment with a synthetic dataset based on the [preference tuning chapter](../../2_preference_alignment/README.md)
